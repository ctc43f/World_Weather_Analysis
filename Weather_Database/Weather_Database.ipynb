# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(-90.000,90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print("The code has randomly generated " + str(len(cities)) + " cities.")
# Out:
# The code has randomly generated 755 cities.

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'https://api.openweathermap.org/data/2.5/weather?' + 'appid=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #https://stackoverflow.com/questions/25855276/parsing-json-with-python-typeerror-list-indices-must-be-integers-not-str
        city_desc = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Desc.": city_desc})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zhezkazgan
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | soyo
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | tavda
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | naryan-mar
# Processing Record 10 of Set 1 | cap malheureux
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | kokkola
# Processing Record 13 of Set 1 | natal
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | mizdah
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | bathsheba
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 1 | chaupimarca
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 1 | keti bandar
# Processing Record 28 of Set 1 | picui
# Processing Record 29 of Set 1 | indiana
# Processing Record 30 of Set 1 | mobaye
# Processing Record 31 of Set 1 | panaba
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | vihari
# Processing Record 34 of Set 1 | melioratorov
# Processing Record 35 of Set 1 | parainen
# Processing Record 36 of Set 1 | marovoay
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | atar
# Processing Record 39 of Set 1 | undory
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | tiznit
# Processing Record 45 of Set 1 | say
# Processing Record 46 of Set 1 | santo antonio de jesus
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | minudasht
# Processing Record 49 of Set 1 | saint anthony
# Processing Record 50 of Set 1 | duverge
# Processing Record 1 of Set 2 | brae
# Processing Record 2 of Set 2 | havoysund
# Processing Record 3 of Set 2 | gat
# Processing Record 4 of Set 2 | mangrol
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | greece
# Processing Record 9 of Set 2 | jalu
# Processing Record 10 of Set 2 | nalhati
# Processing Record 11 of Set 2 | guajara
# Processing Record 12 of Set 2 | huarmey
# Processing Record 13 of Set 2 | lagoa
# Processing Record 14 of Set 2 | bubaque
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | riberalta
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | raudeberg
# Processing Record 19 of Set 2 | encruzilhada do sul
# Processing Record 20 of Set 2 | lincoln
# Processing Record 21 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 2 | diamantino
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | aripuana
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | glazov
# Processing Record 29 of Set 2 | tevriz
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | halifax
# Processing Record 34 of Set 2 | itarema
# Processing Record 35 of Set 2 | ancud
# Processing Record 36 of Set 2 | aksarka
# Processing Record 37 of Set 2 | monrovia
# Processing Record 38 of Set 2 | berlevag
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | rumilly
# Processing Record 41 of Set 2 | san juan
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | monastyrshchina
# Processing Record 44 of Set 2 | wattegama
# Processing Record 45 of Set 2 | camacha
# Processing Record 46 of Set 2 | cheremshan
# Processing Record 47 of Set 2 | osorno
# Processing Record 48 of Set 2 | mercedes
# Processing Record 49 of Set 2 | nadym
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | choma
# Processing Record 3 of Set 3 | strezhevoy
# Processing Record 4 of Set 3 | olafsvik
# Processing Record 5 of Set 3 | muros
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | sinnamary
# Processing Record 8 of Set 3 | iracoubo
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | okakarara
# Processing Record 12 of Set 3 | lakefield
# Processing Record 13 of Set 3 | archidona
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | sioux lookout
# Processing Record 16 of Set 3 | mandera
# Processing Record 17 of Set 3 | monte patria
# Processing Record 18 of Set 3 | chepareria
# Processing Record 19 of Set 3 | bolgatanga
# Processing Record 20 of Set 3 | aleksandrow lodzki
# Processing Record 21 of Set 3 | luderitz
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | tutoia
# Processing Record 25 of Set 3 | trondheim
# Processing Record 26 of Set 3 | thessalon
# Processing Record 27 of Set 3 | sisimiut
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | arenapolis
# Processing Record 32 of Set 3 | gornopravdinsk
# Processing Record 33 of Set 3 | ciudad bolivar
# Processing Record 34 of Set 3 | santa isabel do rio negro
# Processing Record 35 of Set 3 | shimoni
# Processing Record 36 of Set 3 | oussouye
# Processing Record 37 of Set 3 | urucara
# Processing Record 38 of Set 3 | beroroha
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | wamba
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | zaysan
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | nalut
# Processing Record 47 of Set 3 | mgandu
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | namibe
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | nantucket
# Processing Record 2 of Set 4 | nkhotakota
# Processing Record 3 of Set 4 | kayerkan
# Processing Record 4 of Set 4 | grand-santi
# Processing Record 5 of Set 4 | sauda
# Processing Record 6 of Set 4 | vieques
# Processing Record 7 of Set 4 | erice
# Processing Record 8 of Set 4 | pitimbu
# Processing Record 9 of Set 4 | los llanos de aridane
# Processing Record 10 of Set 4 | margate
# Processing Record 11 of Set 4 | comodoro rivadavia
# Processing Record 12 of Set 4 | loiza
# Processing Record 13 of Set 4 | grand gaube
# Processing Record 14 of Set 4 | hakvik
# City not found. Skipping...
# Processing Record 15 of Set 4 | irbit
# Processing Record 16 of Set 4 | abalak
# Processing Record 17 of Set 4 | mogadishu
# Processing Record 18 of Set 4 | esna
# Processing Record 19 of Set 4 | narsaq
# Processing Record 20 of Set 4 | fochville
# Processing Record 21 of Set 4 | miedzychod
# Processing Record 22 of Set 4 | marsa matruh
# Processing Record 23 of Set 4 | pedernales
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 4 | beira
# Processing Record 27 of Set 4 | catamarca
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 4 | springbok
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | moussoro
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | anori
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | safranbolu
# Processing Record 38 of Set 4 | ornes
# Processing Record 39 of Set 4 | normandin
# Processing Record 40 of Set 4 | sao filipe
# Processing Record 41 of Set 4 | samfya
# Processing Record 42 of Set 4 | soligalich
# Processing Record 43 of Set 4 | kidal
# Processing Record 44 of Set 4 | verrettes
# Processing Record 45 of Set 4 | hualmay
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | quatre cocos
# Processing Record 48 of Set 4 | tahta
# Processing Record 49 of Set 4 | diepenbeek
# Processing Record 50 of Set 4 | araouane
# Processing Record 1 of Set 5 | betare oya
# Processing Record 2 of Set 5 | chiplun
# Processing Record 3 of Set 5 | lodeynoye pole
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | usakos
# Processing Record 7 of Set 5 | safaga
# Processing Record 8 of Set 5 | arzgir
# Processing Record 9 of Set 5 | palm coast
# Processing Record 10 of Set 5 | puerto castilla
# Processing Record 11 of Set 5 | mount pleasant
# Processing Record 12 of Set 5 | kumo
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | dakar
# Processing Record 16 of Set 5 | rundu
# Processing Record 17 of Set 5 | areia branca
# Processing Record 18 of Set 5 | romanovka
# Processing Record 19 of Set 5 | reconquista
# Processing Record 20 of Set 5 | san pedro
# Processing Record 21 of Set 5 | emborion
# Processing Record 22 of Set 5 | carlos antonio lopez
# Processing Record 23 of Set 5 | teguise
# Processing Record 24 of Set 5 | salinas
# Processing Record 25 of Set 5 | nizhniy baskunchak
# Processing Record 26 of Set 5 | coreau
# Processing Record 27 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 5 | bagamoyo
# Processing Record 29 of Set 5 | ilulissat
# Processing Record 30 of Set 5 | rawatsar
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | iranshahr
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | tres arroyos
# Processing Record 35 of Set 5 | menongue
# Processing Record 36 of Set 5 | olinda
# Processing Record 37 of Set 5 | rabo de peixe
# Processing Record 38 of Set 5 | robertsport
# Processing Record 39 of Set 5 | biharamulo
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | iralaya
# Processing Record 42 of Set 5 | bajil
# Processing Record 43 of Set 5 | funadhoo
# Processing Record 44 of Set 5 | matagami
# Processing Record 45 of Set 5 | el tigre
# Processing Record 46 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 5 | lebork
# Processing Record 48 of Set 5 | presidencia roque saenz pena
# Processing Record 49 of Set 5 | murgab
# Processing Record 50 of Set 5 | dekar
# Processing Record 1 of Set 6 | paramithia
# City not found. Skipping...
# Processing Record 2 of Set 6 | ibiapina
# Processing Record 3 of Set 6 | port shepstone
# Processing Record 4 of Set 6 | vysha
# Processing Record 5 of Set 6 | rio grande
# Processing Record 6 of Set 6 | akhalgori
# Processing Record 7 of Set 6 | barranca
# Processing Record 8 of Set 6 | jales
# Processing Record 9 of Set 6 | camana
# Processing Record 10 of Set 6 | kirillov
# Processing Record 11 of Set 6 | aras
# Processing Record 12 of Set 6 | quelimane
# Processing Record 13 of Set 6 | koungou
# Processing Record 14 of Set 6 | rumuruti
# Processing Record 15 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 16 of Set 6 | torrington
# Processing Record 17 of Set 6 | nyagan
# Processing Record 18 of Set 6 | carutapera
# Processing Record 19 of Set 6 | alhandra
# Processing Record 20 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 21 of Set 6 | misratah
# Processing Record 22 of Set 6 | altay
# Processing Record 23 of Set 6 | mana
# Processing Record 24 of Set 6 | matadi
# Processing Record 25 of Set 6 | ampanihy
# Processing Record 26 of Set 6 | paamiut
# Processing Record 27 of Set 6 | richards bay
# Processing Record 28 of Set 6 | kyabe
# Processing Record 29 of Set 6 | moose factory
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | talcahuano
# Processing Record 32 of Set 6 | buchanan
# Processing Record 33 of Set 6 | petroussa
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | kashirskoye
# Processing Record 36 of Set 6 | aguimes
# Processing Record 37 of Set 6 | asfi
# Processing Record 38 of Set 6 | taltal
# Processing Record 39 of Set 6 | cangucu
# Processing Record 40 of Set 6 | sosnovo
# Processing Record 41 of Set 6 | buduslau
# Processing Record 42 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | sao desiderio
# Processing Record 45 of Set 6 | pirogovo
# Processing Record 46 of Set 6 | magomeni
# Processing Record 47 of Set 6 | lokosovo
# Processing Record 48 of Set 6 | la asuncion
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | dunmore east
# Processing Record 1 of Set 7 | kulhudhuffushi
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | englewood
# Processing Record 4 of Set 7 | igrim
# Processing Record 5 of Set 7 | kondinskoye
# Processing Record 6 of Set 7 | kathmandu
# Processing Record 7 of Set 7 | kutum
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | tahoua
# Processing Record 10 of Set 7 | nzega
# Processing Record 11 of Set 7 | aswan
# Processing Record 12 of Set 7 | ormara
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | selizharovo
# Processing Record 15 of Set 7 | alenquer
# Processing Record 16 of Set 7 | pirgos
# Processing Record 17 of Set 7 | svetlogorsk
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | viedma
# Processing Record 20 of Set 7 | qaqortoq
# Processing Record 21 of Set 7 | mecca
# Processing Record 22 of Set 7 | beloha
# Processing Record 23 of Set 7 | japura
# Processing Record 24 of Set 7 | robertson
# Processing Record 25 of Set 7 | yining
# Processing Record 26 of Set 7 | sao felix do xingu
# Processing Record 27 of Set 7 | rio pomba
# Processing Record 28 of Set 7 | agadez
# Processing Record 29 of Set 7 | itapirapua
# Processing Record 30 of Set 7 | nhamunda
# Processing Record 31 of Set 7 | solec kujawski
# Processing Record 32 of Set 7 | dorado
# Processing Record 33 of Set 7 | chesma
# Processing Record 34 of Set 7 | sonneberg
# Processing Record 35 of Set 7 | pilane
# Processing Record 36 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 7 | antofagasta
# Processing Record 38 of Set 7 | azuaga
# Processing Record 39 of Set 7 | maues
# Processing Record 40 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 7 | neuquen
# Processing Record 42 of Set 7 | caravelas
# Processing Record 43 of Set 7 | abdanan
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | muzhi
# Processing Record 46 of Set 7 | sabha
# Processing Record 47 of Set 7 | rognan
# Processing Record 48 of Set 7 | ornskoldsvik
# Processing Record 49 of Set 7 | oksfjord
# Processing Record 50 of Set 7 | tandil
# Processing Record 1 of Set 8 | lerwick
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | san andres
# Processing Record 4 of Set 8 | sakaraha
# Processing Record 5 of Set 8 | shar
# Processing Record 6 of Set 8 | manta
# Processing Record 7 of Set 8 | west bay
# Processing Record 8 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 9 of Set 8 | peru
# Processing Record 10 of Set 8 | pascagoula
# Processing Record 11 of Set 8 | hoopstad
# Processing Record 12 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 8 | camargo
# Processing Record 14 of Set 8 | urumqi
# Processing Record 15 of Set 8 | baherden
# Processing Record 16 of Set 8 | zhanaozen
# Processing Record 17 of Set 8 | oliveira dos brejinhos
# Processing Record 18 of Set 8 | dalkola
# Processing Record 19 of Set 8 | mayahi
# Processing Record 20 of Set 8 | dzilam gonzalez
# Processing Record 21 of Set 8 | corn island
# Processing Record 22 of Set 8 | havre-saint-pierre
# Processing Record 23 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 8 | ous
# Processing Record 25 of Set 8 | dipkarpaz
# City not found. Skipping...
# Processing Record 26 of Set 8 | conde
# Processing Record 27 of Set 8 | medea
# Processing Record 28 of Set 8 | plettenberg bay
# Processing Record 29 of Set 8 | coihaique
# Processing Record 30 of Set 8 | maxixe
# Processing Record 31 of Set 8 | rocha
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | oistins
# Processing Record 34 of Set 8 | port-gentil
# Processing Record 35 of Set 8 | sheopur
# Processing Record 36 of Set 8 | walvis bay
# Processing Record 37 of Set 8 | marawi
# Processing Record 38 of Set 8 | sturgeon falls
# Processing Record 39 of Set 8 | riyadh
# Processing Record 40 of Set 8 | socond
# Processing Record 41 of Set 8 | great yarmouth
# Processing Record 42 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 8 | miraflores
# Processing Record 44 of Set 8 | capim grosso
# Processing Record 45 of Set 8 | beyneu
# Processing Record 46 of Set 8 | hornepayne
# Processing Record 47 of Set 8 | kismayo
# Processing Record 48 of Set 8 | salisbury
# Processing Record 49 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 8 | novo mesto
# Processing Record 1 of Set 9 | dunmore town
# Processing Record 2 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | sarankhola
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | malmesbury
# Processing Record 6 of Set 9 | port blair
# Processing Record 7 of Set 9 | bela
# Processing Record 8 of Set 9 | chillan
# Processing Record 9 of Set 9 | harlingen
# Processing Record 10 of Set 9 | mirabad
# Processing Record 11 of Set 9 | nurota
# Processing Record 12 of Set 9 | adilcevaz
# Processing Record 13 of Set 9 | vila do maio
# Processing Record 14 of Set 9 | key west
# Processing Record 15 of Set 9 | inhambane
# Processing Record 16 of Set 9 | mehriz
# Processing Record 17 of Set 9 | lubango
# Processing Record 18 of Set 9 | burgeo
# Processing Record 19 of Set 9 | bhatkal
# Processing Record 20 of Set 9 | maragogi
# Processing Record 21 of Set 9 | saquena
# Processing Record 22 of Set 9 | maureni
# Processing Record 23 of Set 9 | gorokhovets
# Processing Record 24 of Set 9 | iquitos
# Processing Record 25 of Set 9 | oranjemund
# Processing Record 26 of Set 9 | udala
# Processing Record 27 of Set 9 | praia da vitoria
# Processing Record 28 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 29 of Set 9 | raahe
# Processing Record 30 of Set 9 | neustadt
# Processing Record 31 of Set 9 | corrente
# Processing Record 32 of Set 9 | loandjili
# Processing Record 33 of Set 9 | capinzal
# Processing Record 34 of Set 9 | butterworth
# Processing Record 35 of Set 9 | buritis
# Processing Record 36 of Set 9 | igarka
# Processing Record 37 of Set 9 | allentown
# Processing Record 38 of Set 9 | changji
# Processing Record 39 of Set 9 | kalevala
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | vryburg
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | henties bay
# Processing Record 45 of Set 9 | ferme-neuve
# Processing Record 46 of Set 9 | ylivieska
# Processing Record 47 of Set 9 | usta muhammad
# Processing Record 48 of Set 9 | domoni
# Processing Record 49 of Set 9 | gulbarga
# Processing Record 50 of Set 9 | ivanivka
# Processing Record 1 of Set 10 | karrapur
# Processing Record 2 of Set 10 | rudnya
# Processing Record 3 of Set 10 | san juan del sur
# Processing Record 4 of Set 10 | coquimbo
# Processing Record 5 of Set 10 | moissac
# Processing Record 6 of Set 10 | kyzyl-suu
# Processing Record 7 of Set 10 | mango
# Processing Record 8 of Set 10 | bokoro
# Processing Record 9 of Set 10 | santo antonio do ica
# Processing Record 10 of Set 10 | rodas
# Processing Record 11 of Set 10 | varkkallai
# Processing Record 12 of Set 10 | bereda
# Processing Record 13 of Set 10 | camacupa
# Processing Record 14 of Set 10 | beboto
# Processing Record 15 of Set 10 | nara
# Processing Record 16 of Set 10 | abay
# Processing Record 17 of Set 10 | carnarvon
# Processing Record 18 of Set 10 | chapais
# Processing Record 19 of Set 10 | birao
# Processing Record 20 of Set 10 | karasburg
# Processing Record 21 of Set 10 | gelibolu
# Processing Record 22 of Set 10 | uray
# Processing Record 23 of Set 10 | mojo
# Processing Record 24 of Set 10 | kamenka
# Processing Record 25 of Set 10 | himora
# City not found. Skipping...
# Processing Record 26 of Set 10 | bardiyah
# Processing Record 27 of Set 10 | gasa
# Processing Record 28 of Set 10 | venice
# Processing Record 29 of Set 10 | otjiwarongo
# Processing Record 30 of Set 10 | bolu
# Processing Record 31 of Set 10 | tamandare
# Processing Record 32 of Set 10 | remedios
# Processing Record 33 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 10 | caraballeda
# Processing Record 35 of Set 10 | kirando
# Processing Record 36 of Set 10 | espanola
# Processing Record 37 of Set 10 | areado
# Processing Record 38 of Set 10 | male
# Processing Record 39 of Set 10 | buenaventura
# Processing Record 40 of Set 10 | gelemso
# Processing Record 41 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 10 | port said
# Processing Record 43 of Set 10 | abreus
# Processing Record 44 of Set 10 | talnakh
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | ati
# Processing Record 47 of Set 10 | constantine
# Processing Record 48 of Set 10 | mocuba
# Processing Record 49 of Set 10 | nigel
# Processing Record 50 of Set 10 | uusikaupunki
# Processing Record 1 of Set 11 | inirida
# Processing Record 2 of Set 11 | pankovka
# Processing Record 3 of Set 11 | vestmanna
# Processing Record 4 of Set 11 | masvingo
# Processing Record 5 of Set 11 | djougou
# Processing Record 6 of Set 11 | tanabi
# Processing Record 7 of Set 11 | savannah bight
# Processing Record 8 of Set 11 | yakovlevo
# Processing Record 9 of Set 11 | ouadda
# Processing Record 10 of Set 11 | kirovskiy
# Processing Record 11 of Set 11 | barra patuca
# Processing Record 12 of Set 11 | mushie
# Processing Record 13 of Set 11 | abu dhabi
# Processing Record 14 of Set 11 | bonfim
# Processing Record 15 of Set 11 | yalta
# Processing Record 16 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 11 | puerto narino
# Processing Record 18 of Set 11 | santa ana
# Processing Record 19 of Set 11 | ulagan
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | doha
# Processing Record 22 of Set 11 | el wasta
# City not found. Skipping...
# Processing Record 23 of Set 11 | verkhnyaya inta
# Processing Record 24 of Set 11 | sindor
# Processing Record 25 of Set 11 | bodden town
# Processing Record 26 of Set 11 | arlit
# Processing Record 27 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 28 of Set 11 | sept-iles
# Processing Record 29 of Set 11 | ponta delgada
# Processing Record 30 of Set 11 | sao sebastiao
# Processing Record 31 of Set 11 | sudak
# Processing Record 32 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 11 | belyy yar
# Processing Record 34 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 11 | goya
# Processing Record 36 of Set 11 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 37 of Set 11 | le vauclin
# Processing Record 38 of Set 11 | santa marinella
# Processing Record 39 of Set 11 | beinamar
# Processing Record 40 of Set 11 | kuytun
# Processing Record 41 of Set 11 | nuuk
# Processing Record 42 of Set 11 | pattoki
# Processing Record 43 of Set 11 | talara
# Processing Record 44 of Set 11 | dori
# Processing Record 45 of Set 11 | araguaina
# Processing Record 46 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 47 of Set 11 | takoradi
# Processing Record 48 of Set 11 | kabompo
# Processing Record 49 of Set 11 | newcastle
# Processing Record 50 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 12 | zomba
# Processing Record 2 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 3 of Set 12 | mega
# Processing Record 4 of Set 12 | bowmore
# Processing Record 5 of Set 12 | jizan
# Processing Record 6 of Set 12 | kuruman
# Processing Record 7 of Set 12 | lunenburg
# Processing Record 8 of Set 12 | sao gabriel da cachoeira
# Processing Record 9 of Set 12 | holland
# Processing Record 10 of Set 12 | bilma
# Processing Record 11 of Set 12 | iaciara
# Processing Record 12 of Set 12 | marzuq
# Processing Record 13 of Set 12 | divo
# Processing Record 14 of Set 12 | tessalit
# Processing Record 15 of Set 12 | teguldet
# Processing Record 16 of Set 12 | bumba
# Processing Record 17 of Set 12 | watsa
# Processing Record 18 of Set 12 | oum hadjer
# Processing Record 19 of Set 12 | volta redonda
# Processing Record 20 of Set 12 | djenne
# Processing Record 21 of Set 12 | rawson
# Processing Record 22 of Set 12 | kambove
# Processing Record 23 of Set 12 | juba
# Processing Record 24 of Set 12 | abrau-dyurso
# Processing Record 25 of Set 12 | angoche
# Processing Record 26 of Set 12 | umba
# Processing Record 27 of Set 12 | chiredzi
# Processing Record 28 of Set 12 | sao mateus
# Processing Record 29 of Set 12 | cabras
# Processing Record 30 of Set 12 | bure
# Processing Record 31 of Set 12 | upington
# Processing Record 32 of Set 12 | ermelo
# Processing Record 33 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 12 | mattru
# Processing Record 35 of Set 12 | san lawrenz
# Processing Record 36 of Set 12 | high rock
# Processing Record 37 of Set 12 | naifaru
# Processing Record 38 of Set 12 | colonial park
# Processing Record 39 of Set 12 | sommerda
# City not found. Skipping...
# Processing Record 40 of Set 12 | sikasso
# Processing Record 41 of Set 12 | bengkulu
# Processing Record 42 of Set 12 | roald
# Processing Record 43 of Set 12 | terra santa
# Processing Record 44 of Set 12 | valkeala
# Processing Record 45 of Set 12 | udomlya
# Processing Record 46 of Set 12 | vagur
# Processing Record 47 of Set 12 | storforshei
# Processing Record 48 of Set 12 | beni suef
# Processing Record 49 of Set 12 | kenitra
# Processing Record 50 of Set 12 | frederico westphalen
# Processing Record 1 of Set 13 | tamala
# Processing Record 2 of Set 13 | luga
# Processing Record 3 of Set 13 | lethem
# Processing Record 4 of Set 13 | gurkovo
# Processing Record 5 of Set 13 | puerto colombia
# Processing Record 6 of Set 13 | medvedka
# Processing Record 7 of Set 13 | shache
# Processing Record 8 of Set 13 | ambilobe
# Processing Record 9 of Set 13 | rochegda
# Processing Record 10 of Set 13 | paulo afonso
# Processing Record 11 of Set 13 | mbandaka
# Processing Record 12 of Set 13 | thompson
# Processing Record 13 of Set 13 | syamzha
# Processing Record 14 of Set 13 | hofn
# Processing Record 15 of Set 13 | manakara
# Processing Record 16 of Set 13 | bandarbeyla
# Processing Record 17 of Set 13 | saint-francois
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | bad doberan
# Processing Record 21 of Set 13 | kangaba
# Processing Record 22 of Set 13 | ostrogozhsk
# Processing Record 23 of Set 13 | paso de carrasco
# Processing Record 24 of Set 13 | marsh harbour
# Processing Record 25 of Set 13 | yarada
# Processing Record 26 of Set 13 | coruripe
# Processing Record 27 of Set 13 | la paz
# Processing Record 28 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 13 | tocopilla
# Processing Record 30 of Set 13 | tanout
# Processing Record 31 of Set 13 | nikel
# Processing Record 32 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 13 | warrington
# Processing Record 34 of Set 13 | brigantine
# Processing Record 35 of Set 13 | porto walter
# Processing Record 36 of Set 13 | akot
# Processing Record 37 of Set 13 | majholi
# Processing Record 38 of Set 13 | mahanoro
# Processing Record 39 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 13 | cololaca
# Processing Record 41 of Set 13 | saryagash
# Processing Record 42 of Set 13 | gayny
# Processing Record 43 of Set 13 | isla mujeres
# Processing Record 44 of Set 13 | bonthe
# Processing Record 45 of Set 13 | carballo
# Processing Record 46 of Set 13 | altrincham
# Processing Record 47 of Set 13 | buta
# Processing Record 48 of Set 13 | alta floresta
# Processing Record 49 of Set 13 | shieli
# Processing Record 50 of Set 13 | mayumba
# Processing Record 1 of Set 14 | kastamonu
# Processing Record 2 of Set 14 | nikki
# Processing Record 3 of Set 14 | arua
# Processing Record 4 of Set 14 | goryachegorsk
# Processing Record 5 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 14 | inverness
# Processing Record 7 of Set 14 | senneterre
# Processing Record 8 of Set 14 | acari
# Processing Record 9 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 10 of Set 14 | custoias
# Processing Record 11 of Set 14 | frolovo
# Processing Record 12 of Set 14 | almeirim
# Processing Record 13 of Set 14 | andselv
# City not found. Skipping...
# Processing Record 14 of Set 14 | opuwo
# Processing Record 15 of Set 14 | ratnagiri
# Processing Record 16 of Set 14 | manoharpur
# Processing Record 17 of Set 14 | kralendijk
# Processing Record 18 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 14 | araxa
# Processing Record 20 of Set 14 | mamallapuram
# Processing Record 21 of Set 14 | beni mazar
# Processing Record 22 of Set 14 | bud
# Processing Record 23 of Set 14 | pilar
# Processing Record 24 of Set 14 | dhidhdhoo
# Processing Record 25 of Set 14 | praia
# Processing Record 26 of Set 14 | darnah
# Processing Record 27 of Set 14 | arras
# Processing Record 28 of Set 14 | kholmogory
# Processing Record 29 of Set 14 | deer lake
# Processing Record 30 of Set 14 | boende
# Processing Record 31 of Set 14 | le pradet
# Processing Record 32 of Set 14 | colesberg
# Processing Record 33 of Set 14 | pedasi
# Processing Record 34 of Set 14 | yithion
# City not found. Skipping...
# Processing Record 35 of Set 14 | ovalle
# Processing Record 36 of Set 14 | pangoa
# Processing Record 37 of Set 14 | chingirlau
# Processing Record 38 of Set 14 | raniganj
# Processing Record 39 of Set 14 | maniitsoq
# Processing Record 40 of Set 14 | adeje
# Processing Record 41 of Set 14 | dawlatabad
# Processing Record 42 of Set 14 | staryy nadym
# Processing Record 43 of Set 14 | grand-lahou
# Processing Record 44 of Set 14 | ust-tsilma
# Processing Record 45 of Set 14 | envira
# Processing Record 46 of Set 14 | hendrina
# Processing Record 47 of Set 14 | mozarlandia
# Processing Record 48 of Set 14 | mwinilunga
# Processing Record 49 of Set 14 | abdulino
# Processing Record 50 of Set 14 | carauari
# Processing Record 1 of Set 15 | carmen
# Processing Record 2 of Set 15 | tabas
# Processing Record 3 of Set 15 | iskateley
# Processing Record 4 of Set 15 | amapa
# Processing Record 5 of Set 15 | disna
# Processing Record 6 of Set 15 | mahibadhoo
# Processing Record 7 of Set 15 | plesetsk
# Processing Record 8 of Set 15 | talesh
# City not found. Skipping...
# Processing Record 9 of Set 15 | san ramon
# Processing Record 10 of Set 15 | namestovo
# Processing Record 11 of Set 15 | mumford
# Processing Record 12 of Set 15 | andenes
# Processing Record 13 of Set 15 | trairi
# Processing Record 14 of Set 15 | coihueco
# Processing Record 15 of Set 15 | athy
# Processing Record 16 of Set 15 | santo amaro da imperatriz
# Processing Record 17 of Set 15 | port hawkesbury
# Processing Record 18 of Set 15 | novyy urengoy
# Processing Record 19 of Set 15 | chimbote
# Processing Record 20 of Set 15 | umm lajj
# Processing Record 21 of Set 15 | otjimbingwe
# Processing Record 22 of Set 15 | limulunga
# Processing Record 23 of Set 15 | ambikapur
# Processing Record 24 of Set 15 | puerto ayora
# Processing Record 25 of Set 15 | dwarka
# Processing Record 26 of Set 15 | channarayapatna
# Processing Record 27 of Set 15 | pauini
# Processing Record 28 of Set 15 | valparaiso
# Processing Record 29 of Set 15 | mineros
# Processing Record 30 of Set 15 | havelock
# Processing Record 31 of Set 15 | umarkot
# Processing Record 32 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 15 | saint-augustin
# Processing Record 34 of Set 15 | mayor pablo lagerenza
# Processing Record 35 of Set 15 | conceicao do araguaia
# Processing Record 36 of Set 15 | eyl
# Processing Record 37 of Set 15 | vallenar
# Processing Record 38 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 15 | mendoza
# Processing Record 40 of Set 15 | valer
# Processing Record 41 of Set 15 | santa cruz de la palma
# Processing Record 42 of Set 15 | pachperwa
# Processing Record 43 of Set 15 | cabedelo
# Processing Record 44 of Set 15 | kindu
# Processing Record 45 of Set 15 | odweyne
# Processing Record 46 of Set 15 | nicoya
# Processing Record 47 of Set 15 | laurel
# Processing Record 48 of Set 15 | maarianhamina
# Processing Record 49 of Set 15 | candolim
# Processing Record 50 of Set 15 | jacareacanga
# Processing Record 1 of Set 16 | olavarria
# Processing Record 2 of Set 16 | baneh
# Processing Record 3 of Set 16 | kolondieba
# Processing Record 4 of Set 16 | pescia
# Processing Record 5 of Set 16 | peniche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print("The code successfully generated " +  str(len(city_data)) + " cities.")
# Out:
# The code successfully generated 698 cities.

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City  Cloudiness Country                 Date             Desc.  \
# 0      Zhezkazgan          99      KZ  2022-10-30 20:48:56   overcast clouds
# 1         Ushuaia          40      AR  2022-10-30 20:48:56  scattered clouds
# 2       Jamestown           0      US  2022-10-30 20:48:56         clear sky
# 3            Soyo          97      AO  2022-10-30 20:48:57   overcast clouds
# 4    Saint George           0      US  2022-10-30 20:37:27         clear sky
# 5           Tavda          93      RU  2022-10-30 20:48:57   overcast clouds
# 6          Torbay          75      CA  2022-10-30 20:39:57     broken clouds
# 7       Cape Town          20      ZA  2022-10-30 20:44:19        few clouds
# 8      Naryan-Mar         100      RU  2022-10-30 20:49:19   overcast clouds
# 9  Cap Malheureux         100      MU  2022-10-30 20:49:20   overcast clouds
#
#    Humidity      Lat       Lng  Max Temp  Wind Speed
# 0        76  47.8043   67.7144    277.16        3.48
# 1        70 -54.8000  -68.3000    279.96       16.46
# 2        21  42.0970  -79.2353    290.95        2.06
# 3        86  -6.1349   12.3689    299.07        3.67
# 4        20  37.1041 -113.5841    294.79        2.06
# 5        70  58.0425   65.2726    270.07        4.57
# 6        78  47.6666  -52.7314    284.97        7.72
# 7        65 -33.9258   18.4232    288.86       10.80
# 8        93  67.6713   53.0870    274.40        6.07
# 9        68 -19.9842   57.6142    296.19        2.24

# %%
#Convert the max temp column to farenheit
city_data_df["Max Temp"] = (9/5) * (city_data_df["Max Temp"] - 273.15) + 32

# %%
city_data_df.head(10)
# Out:
#              City  Cloudiness Country                 Date             Desc.  \
# 0      Zhezkazgan          99      KZ  2022-10-30 20:48:56   overcast clouds
# 1         Ushuaia          40      AR  2022-10-30 20:48:56  scattered clouds
# 2       Jamestown           0      US  2022-10-30 20:48:56         clear sky
# 3            Soyo          97      AO  2022-10-30 20:48:57   overcast clouds
# 4    Saint George           0      US  2022-10-30 20:37:27         clear sky
# 5           Tavda          93      RU  2022-10-30 20:48:57   overcast clouds
# 6          Torbay          75      CA  2022-10-30 20:39:57     broken clouds
# 7       Cape Town          20      ZA  2022-10-30 20:44:19        few clouds
# 8      Naryan-Mar         100      RU  2022-10-30 20:49:19   overcast clouds
# 9  Cap Malheureux         100      MU  2022-10-30 20:49:20   overcast clouds
#
#    Humidity      Lat       Lng  Max Temp  Wind Speed
# 0        76  47.8043   67.7144    39.218        3.48
# 1        70 -54.8000  -68.3000    44.258       16.46
# 2        21  42.0970  -79.2353    64.040        2.06
# 3        86  -6.1349   12.3689    78.656        3.67
# 4        20  37.1041 -113.5841    70.952        2.06
# 5        70  58.0425   65.2726    26.456        4.57
# 6        78  47.6666  -52.7314    53.276        7.72
# 7        65 -33.9258   18.4232    60.278       10.80
# 8        93  67.6713   53.0870    34.250        6.07
# 9        68 -19.9842   57.6142    73.472        2.24

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Date', 'Desc.', 'Humidity', 'Lat',
#        'Lng', 'Max Temp', 'Wind Speed'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
my_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  
                   "Desc."]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[my_column_order]
city_data_df.rename(columns={"Desc.": "Current Description"}, inplace = True)

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Zhezkazgan      KZ  47.8043   67.7144    39.218        76          99
# 1         Ushuaia      AR -54.8000  -68.3000    44.258        70          40
# 2       Jamestown      US  42.0970  -79.2353    64.040        21           0
# 3            Soyo      AO  -6.1349   12.3689    78.656        86          97
# 4    Saint George      US  37.1041 -113.5841    70.952        20           0
# 5           Tavda      RU  58.0425   65.2726    26.456        70          93
# 6          Torbay      CA  47.6666  -52.7314    53.276        78          75
# 7       Cape Town      ZA -33.9258   18.4232    60.278        65          20
# 8      Naryan-Mar      RU  67.6713   53.0870    34.250        93         100
# 9  Cap Malheureux      MU -19.9842   57.6142    73.472        68         100
#
#    Wind Speed Current Description
# 0        3.48     overcast clouds
# 1       16.46    scattered clouds
# 2        2.06           clear sky
# 3        3.67     overcast clouds
# 4        2.06           clear sky
# 5        4.57     overcast clouds
# 6        7.72       broken clouds
# 7       10.80          few clouds
# 8        6.07     overcast clouds
# 9        2.24     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_filename = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_filename, index_label = "City_ID")
